# %% [markdown]
# ## Notebook to scrape all cases from Refugee Law Lab Reporter Website
#
# Requirements:
#
#     pip install requests
#     pip install bs4
#     pip install pandas
#     pip install tqdm
#
# (Produced on Python 3.9.12)

# %% [markdown]
# ### Setup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import pathlib

# set up progress bar
from tqdm import tqdm
tqdm.pandas()

# set up paths
out_path_yearly = pathlib.Path('DATA/YEARLY/')

# set up years sought
start_year = 2019
end_year = 2022

# %% [markdown]
# ### Scrape table of cases from RLL website

# %%
# get table from RLLR Website
url = 'https://refugeelab.ca/rllr/'
r = requests.get(url)
print(r.status_code)

# get first table
soup = BeautifulSoup(r.text, 'html.parser')
table = soup.find('table')

# put table into dataframe
df = pd.read_html(str(table))[0]

# add link to each row
base_url = 'https://refugeelab.ca/rllr/'
df['Link'] = df['Citation & Link'].apply(lambda x: base_url + x.replace(' ', '').lower())

# drop 'Citation Sort (Hidden)' column
df.drop('Citation Sort (Hidden)', axis=1, inplace=True)

# change 'Citation & Link' to 'citation'
df.rename(columns={'Citation & Link': 'citation'}, inplace=True)

# change Date of Decision to "decision_date"
df.rename(columns={'Date of Decision': 'document_date'}, inplace=True)

# for all column names, replace spaces with underscores and lower
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

df
# Out:
# 200
#          citation      country                         case_type  \
# 0     2022 RLLR 1      Nigeria        PSG: Gender Based Violence
# 1    2021 RLLR 76      Nigeria                        PSG: SOGIE
# 2    2021 RLLR 75  South Korea                        PSG: SOGIE
# 3    2021 RLLR 74       Malawi                        PSG: SOGIE
# 4    2021 RLLR 73         Iran                        PSG: SOGIE
# ..            ...          ...                               ...
# 475   2019 RLLR 5        Haiti                        PSG: SOGIE
# 476   2019 RLLR 4        Haiti        PSG: Gender Based Violence
# 477   2019 RLLR 3        Haiti  No Nexus: Criminality/Corruption
# 478   2019 RLLR 2      Nigeria                        PSG: SOGIE
# 479   2019 RLLR 1      Nigeria  No Nexus: Criminality/Corruption
#
#     document_date rpd_number                                   link
# 0      2022/04/29  TB8-20107   https://refugeelab.ca/rllr/2022rllr1
# 1      2021/12/21  VC1-06497  https://refugeelab.ca/rllr/2021rllr76
# 2      2021/11/19  VC1-05121  https://refugeelab.ca/rllr/2021rllr75
# 3      2021/06/14  VC1-02500  https://refugeelab.ca/rllr/2021rllr74
# 4      2021/10/30  VC1-02405  https://refugeelab.ca/rllr/2021rllr73
# ..            ...        ...                                    ...
# 475    2019/10/17  MB7-21566   https://refugeelab.ca/rllr/2019rllr5
# 476    2019/07/04  MB7-18975   https://refugeelab.ca/rllr/2019rllr4
# 477    2019/09/10  MB7-18354   https://refugeelab.ca/rllr/2019rllr3
# 478    2019/12/23  TB9-01394   https://refugeelab.ca/rllr/2019rllr2
# 479    2019/10/28  TB9-04813   https://refugeelab.ca/rllr/2019rllr1
#
# [480 rows x 6 columns]

# %% [markdown]
# ### Scrape html for each case in the table

# %%
# function to get the html from the link
def get_html(link):
    r = requests.get(link)
    if r.status_code == 200:
        time.sleep(.25)
        return r.text
    else:
        return None

df['html'] = df.link.progress_apply(get_html)
# Out:
# 100%|██████████| 480/480 [08:14<00:00,  1.03s/it]

# %%
# export to jsonl raw 
df.to_json('DATA/rllr_cases_raw.jsonl', orient='records', lines=True)

df
# Out:
#          citation      country                         case_type  \
# 0     2022 RLLR 1      Nigeria        PSG: Gender Based Violence
# 1    2021 RLLR 76      Nigeria                        PSG: SOGIE
# 2    2021 RLLR 75  South Korea                        PSG: SOGIE
# 3    2021 RLLR 74       Malawi                        PSG: SOGIE
# 4    2021 RLLR 73         Iran                        PSG: SOGIE
# ..            ...          ...                               ...
# 475   2019 RLLR 5        Haiti                        PSG: SOGIE
# 476   2019 RLLR 4        Haiti        PSG: Gender Based Violence
# 477   2019 RLLR 3        Haiti  No Nexus: Criminality/Corruption
# 478   2019 RLLR 2      Nigeria                        PSG: SOGIE
# 479   2019 RLLR 1      Nigeria  No Nexus: Criminality/Corruption
#
#     document_date rpd_number                                   link  \
# 0      2022/04/29  TB8-20107   https://refugeelab.ca/rllr/2022rllr1
# 1      2021/12/21  VC1-06497  https://refugeelab.ca/rllr/2021rllr76
# 2      2021/11/19  VC1-05121  https://refugeelab.ca/rllr/2021rllr75
# 3      2021/06/14  VC1-02500  https://refugeelab.ca/rllr/2021rllr74
# 4      2021/10/30  VC1-02405  https://refugeelab.ca/rllr/2021rllr73
# ..            ...        ...                                    ...
# 475    2019/10/17  MB7-21566   https://refugeelab.ca/rllr/2019rllr5
# 476    2019/07/04  MB7-18975   https://refugeelab.ca/rllr/2019rllr4
# 477    2019/09/10  MB7-18354   https://refugeelab.ca/rllr/2019rllr3
# 478    2019/12/23  TB9-01394   https://refugeelab.ca/rllr/2019rllr2
# 479    2019/10/28  TB9-04813   https://refugeelab.ca/rllr/2019rllr1
#
#                                                   html
# 0    <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# 1    <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# 2    <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# 3    <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# 4    <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# ..                                                 ...
# 475  <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# 476  <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# 477  <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# 478  <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
# 479  <!DOCTYPE html><html\nclass=no-js dir=ltr lang...
#
# [480 rows x 7 columns]

# %% [markdown]
# ### Parse html for each case

# %%
# load raw cases
df = pd.read_json('DATA/rllr_cases_raw.jsonl', orient='records', lines=True)

# %%
# function to extract text from html
def get_text(html):

    # if html is None, return None
    if html is None:
        return None

    # extract text from class 'entry-content' in page1 html using beautiful soup
    soup = BeautifulSoup(html, 'html.parser')

    # convert <br> to new line to preserve paragraphs
    for br in soup.find_all('br'):
        br.replace_with('\n')

    # Insert newline characters after each <p> tag to preserve paragraphs
    for p in soup.find_all('p'):
        p.insert_after('\n')


    # extract text from class 'entry-content' (remove \xa0)
    text = soup.find('div', {'class': 'entry-content'}).text.replace('\xa0', ' ')

    # Remove multiple whitespaces and preserve paragraphs
    text = '\n'.join([re.sub(r'\s+', ' ', line.strip()) for line in text.split('\n')])
    return text

df['text'] = df.html.progress_apply(get_text)

# drop html column
df.drop('html', axis=1, inplace=True)
# Out:
# 100%|██████████| 480/480 [00:08<00:00, 59.40it/s]

# %%
# function to extract RPD_member from text
def get_member(text):
    if text is None:
        return None
    else:
        # if text contains 'Panel:' extract the text after 'Panel:' and before the next newline
        if 'Panel:' in text:
            return re.search(r'Panel:(.*)\n', text).group(1).strip()
        else:
            return None
    
df['member'] = df.text.progress_apply(get_member)
# Out:
# 100%|██████████| 480/480 [00:00<00:00, 480149.28it/s]

# %%
# put in standard format for RLL (except "other" field)

# create language column with value "en"
df['language'] = "en"

# create dataset column with value "RLLR"
df['dataset'] = "RLLR"

# create year column with first 4 characters of citation:
df['year'] = df.citation.str[:4]
df['year'] = df['year'].astype(int)

# add a name column with value ""
df['name'] = ""

# rename rpd_number to citation2
df.rename(columns={'rpd_number': 'citation2'}, inplace=True)

# rename link column to source_url
df.rename(columns={'link': 'source_url'}, inplace=True)

# rename text column to unofficial_text
df.rename(columns={'text': 'unofficial_text'}, inplace=True)

# add a scraped timestamp column with today's date in YYYY-MM-DD format as a string
df['scraped_timestamp'] = pd.Timestamp.today().strftime('%Y-%m-%d')

# add a column for other that takes "country", "case_type", and "member" columns
# and puts them in a dictionary using valid json format
df['other'] = df[['country', 'case_type', 'member']].to_dict(orient='records')

# reorder columns
list_cols = ['citation',
             'citation2', 
             'dataset', 
             'year', 
             'name', 
             'language', 
             'document_date', 
             'source_url', 
             'scraped_timestamp', 
             'unofficial_text',
             'other',
             ]

df = df[list_cols]

# %%
# export to json as a single file
df.to_json('DATA/rllr_cases.jsonl', orient='records', lines=True)

df
# Out:
#          citation  citation2 dataset  year name language document_date  \
# 0     2022 RLLR 1  TB8-20107    RLLR  2022            en    2022/04/29
# 1    2021 RLLR 76  VC1-06497    RLLR  2021            en    2021/12/21
# 2    2021 RLLR 75  VC1-05121    RLLR  2021            en    2021/11/19
# 3    2021 RLLR 74  VC1-02500    RLLR  2021            en    2021/06/14
# 4    2021 RLLR 73  VC1-02405    RLLR  2021            en    2021/10/30
# ..            ...        ...     ...   ...  ...      ...           ...
# 475   2019 RLLR 5  MB7-21566    RLLR  2019            en    2019/10/17
# 476   2019 RLLR 4  MB7-18975    RLLR  2019            en    2019/07/04
# 477   2019 RLLR 3  MB7-18354    RLLR  2019            en    2019/09/10
# 478   2019 RLLR 2  TB9-01394    RLLR  2019            en    2019/12/23
# 479   2019 RLLR 1  TB9-04813    RLLR  2019            en    2019/10/28
#
#                                 source_url scraped_timestamp  \
# 0     https://refugeelab.ca/rllr/2022rllr1        2023-07-17
# 1    https://refugeelab.ca/rllr/2021rllr76        2023-07-17
# 2    https://refugeelab.ca/rllr/2021rllr75        2023-07-17
# 3    https://refugeelab.ca/rllr/2021rllr74        2023-07-17
# 4    https://refugeelab.ca/rllr/2021rllr73        2023-07-17
# ..                                     ...               ...
# 475   https://refugeelab.ca/rllr/2019rllr5        2023-07-17
# 476   https://refugeelab.ca/rllr/2019rllr4        2023-07-17
# 477   https://refugeelab.ca/rllr/2019rllr3        2023-07-17
# 478   https://refugeelab.ca/rllr/2019rllr2        2023-07-17
# 479   https://refugeelab.ca/rllr/2019rllr1        2023-07-17
#
#                                        unofficial_text  \
# 0    Citation: 2022 RLLR 1\nTribunal: Refugee Prote...
# 1    Citation: 2021 RLLR 76\nTribunal: Refugee Prot...
# 2    Citation: 2021 RLLR 75\nTribunal: Refugee Prot...
# 3    Citation: 2021 RLLR 74\nTribunal: Refugee Prot...
# 4    Citation: 2021 RLLR 73\nTribunal: Refugee Prot...
# ..                                                 ...
# 475  Citation: 2019 RLLR 5\nTribunal: Refugee Prote...
# 476  Citation: 2019 RLLR 4\nTribunal: Refugee Prote...
# 477  Citation: 2019 RLLR 3\nTribunal: Refugee Prote...
# 478  Citation: 2019 RLLR 2\nTribunal: Refugee Prote...
# 479  Citation: 2019 RLLR 1\nTribunal: Refugee Prote...
#
#                                                  other
# 0    {'country': 'Nigeria', 'case_type': 'PSG: Gend...
# 1    {'country': 'Nigeria', 'case_type': 'PSG: SOGI...
# 2    {'country': 'South Korea', 'case_type': 'PSG: ...
# 3    {'country': 'Malawi', 'case_type': 'PSG: SOGIE...
# 4    {'country': 'Iran', 'case_type': 'PSG: SOGIE',...
# ..                                                 ...
# 475  {'country': 'Haiti', 'case_type': 'PSG: SOGIE'...
# 476  {'country': 'Haiti', 'case_type': 'PSG: Gender...
# 477  {'country': 'Haiti', 'case_type': 'No Nexus: C...
# 478  {'country': 'Nigeria', 'case_type': 'PSG: SOGI...
# 479  {'country': 'Nigeria', 'case_type': 'No Nexus:...
#
# [480 rows x 11 columns]

# %%
# export cleaned df to parquet
df.to_parquet("DATA/rllr_cases.parquet")

# %%
# export cleaned df to yearly json files
for year in tqdm(range(start_year, end_year+1)):
    df[df.year == year].to_json(out_path_yearly / f'{year}.json', orient='records', indent=4)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 181.84it/s]

# %% [markdown]
# ### Data verification

# %%
#load json
df = pd.read_json('DATA/rllr_cases.jsonl', orient='records', lines=True)

# convert each item in other dictionary to column
df = pd.concat([df.drop(['other'], axis=1), df['other'].apply(pd.Series)], axis=1)
df
# Out:
#          citation  citation2 dataset  year name language document_date  \
# 0     2022 RLLR 1  TB8-20107    RLLR  2022            en    2022/04/29
# 1    2021 RLLR 76  VC1-06497    RLLR  2021            en    2021/12/21
# 2    2021 RLLR 75  VC1-05121    RLLR  2021            en    2021/11/19
# 3    2021 RLLR 74  VC1-02500    RLLR  2021            en    2021/06/14
# 4    2021 RLLR 73  VC1-02405    RLLR  2021            en    2021/10/30
# ..            ...        ...     ...   ...  ...      ...           ...
# 475   2019 RLLR 5  MB7-21566    RLLR  2019            en    2019/10/17
# 476   2019 RLLR 4  MB7-18975    RLLR  2019            en    2019/07/04
# 477   2019 RLLR 3  MB7-18354    RLLR  2019            en    2019/09/10
# 478   2019 RLLR 2  TB9-01394    RLLR  2019            en    2019/12/23
# 479   2019 RLLR 1  TB9-04813    RLLR  2019            en    2019/10/28
#
#                                 source_url scraped_timestamp  \
# 0     https://refugeelab.ca/rllr/2022rllr1        2023-07-17
# 1    https://refugeelab.ca/rllr/2021rllr76        2023-07-17
# 2    https://refugeelab.ca/rllr/2021rllr75        2023-07-17
# 3    https://refugeelab.ca/rllr/2021rllr74        2023-07-17
# 4    https://refugeelab.ca/rllr/2021rllr73        2023-07-17
# ..                                     ...               ...
# 475   https://refugeelab.ca/rllr/2019rllr5        2023-07-17
# 476   https://refugeelab.ca/rllr/2019rllr4        2023-07-17
# 477   https://refugeelab.ca/rllr/2019rllr3        2023-07-17
# 478   https://refugeelab.ca/rllr/2019rllr2        2023-07-17
# 479   https://refugeelab.ca/rllr/2019rllr1        2023-07-17
#
#                                        unofficial_text      country  \
# 0    Citation: 2022 RLLR 1\nTribunal: Refugee Prote...      Nigeria
# 1    Citation: 2021 RLLR 76\nTribunal: Refugee Prot...      Nigeria
# 2    Citation: 2021 RLLR 75\nTribunal: Refugee Prot...  South Korea
# 3    Citation: 2021 RLLR 74\nTribunal: Refugee Prot...       Malawi
# 4    Citation: 2021 RLLR 73\nTribunal: Refugee Prot...         Iran
# ..                                                 ...          ...
# 475  Citation: 2019 RLLR 5\nTribunal: Refugee Prote...        Haiti
# 476  Citation: 2019 RLLR 4\nTribunal: Refugee Prote...        Haiti
# 477  Citation: 2019 RLLR 3\nTribunal: Refugee Prote...        Haiti
# 478  Citation: 2019 RLLR 2\nTribunal: Refugee Prote...      Nigeria
# 479  Citation: 2019 RLLR 1\nTribunal: Refugee Prote...      Nigeria
#
#                             case_type                  member
# 0          PSG: Gender Based Violence                M. Gayda
# 1                          PSG: SOGIE          Lesley Stalker
# 2                          PSG: SOGIE             David Jones
# 3                          PSG: SOGIE          Jennifer Smith
# 4                          PSG: SOGIE  Isis Marianne van Loon
# ..                                ...                     ...
# 475                        PSG: SOGIE         Ethan McMonagle
# 476        PSG: Gender Based Violence         Nicole Ginsberg
# 477  No Nexus: Criminality/Corruption         Me Jean-Guy Jam
# 478                        PSG: SOGIE       Marcelle Bourassa
# 479  No Nexus: Criminality/Corruption       Marcelle Bourassa
#
# [480 rows x 13 columns]

# %%
# function to extract rpd_number from text
def get_rpd_number(text):
    if text is None:
        return None
    else:
        # if text contains 'RPD:' extract the text after 'RPD:' and before the next newline
        if 'RPD Number:' in text:
            return re.search(r'RPD Number:(.*)\n', text).group(1).strip()
        else:
            return None

df['rpd_number'] = df.unofficial_text.progress_apply(get_rpd_number)

# print df where rpd_number2 is not same as rpd_number
df[df.rpd_number != df['citation2']]
# Out:
# 100%|██████████| 480/480 [00:00<00:00, 492481.88it/s]
# Empty DataFrame
# Columns: [citation, citation2, dataset, year, name, language, document_date, source_url, scraped_timestamp, unofficial_text, country, case_type, member, rpd_number]
# Index: []
