# %% [markdown]
# ## Notebook to scrape all cases from Refugee Law Lab Reporter Website
#
# Requirements:
#
#     pip install requests
#     pip install bs4
#     pip install pandas
#     pip install tqdm
#
# (Produced on Python 3.9.12)

# %% [markdown]
# ### Setup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import pathlib
import json

# set up progress bar
from tqdm import tqdm
tqdm.pandas()

# set up paths
out_path_yearly = pathlib.Path('DATA/YEARLY/')

# set up years sought
start_year = 2019
end_year = 2022

# %% [markdown]
# ### Scrape table of cases from RLL website

# %%
# get table from RLLR Website
url = 'https://refugeelab.ca/rllr/'
r = requests.get(url)
print(r.status_code)

# get first table
soup = BeautifulSoup(r.text, 'html.parser')
table = soup.find('table')

# put table into dataframe
df = pd.read_html(str(table))[0]

# add link to each row
base_url = 'https://refugeelab.ca/rllr/'
df['Link'] = df['Citation & Link'].apply(lambda x: base_url + x.replace(' ', '').lower())

# drop 'Citation Sort (Hidden)' column
df.drop('Citation Sort (Hidden)', axis=1, inplace=True)

# change 'Citation & Link' to 'citation'
df.rename(columns={'Citation & Link': 'citation'}, inplace=True)

# change Date of Decision to "decision_date"
df.rename(columns={'Date of Decision': 'document_date'}, inplace=True)

# for all column names, replace spaces with underscores and lower
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

df
# Out:
# 200
#          citation   country                         case_type document_date
# 0    2022 RLLR 32    Mexico        PSG: Gender Based Violence    2022/03/08  \
# 1    2022 RLLR 31     Sudan                 Political Opinion    2022/02/03
# 2    2022 RLLR 30  Barbados        PSG: Gender Based Violence    2022/11/28
# 3    2022 RLLR 29   Ukraine        PSG: Gender Based Violence    2022/11/09
# 4    2022 RLLR 28     India                 Political Opinion    2022/09/28
# ..            ...       ...                               ...           ...
# 534   2019 RLLR 5     Haiti                        PSG: SOGIE    2019/10/17
# 535   2019 RLLR 4     Haiti        PSG: Gender Based Violence    2019/07/04
# 536   2019 RLLR 3     Haiti  No Nexus: Criminality/Corruption    2019/09/10
# 537   2019 RLLR 2   Nigeria                        PSG: SOGIE    2019/12/23
# 538   2019 RLLR 1   Nigeria  No Nexus: Criminality/Corruption    2019/10/28
#
#     rpd_number                                   link
# 0    VC1-05483  https://refugeelab.ca/rllr/2022rllr32
# 1    VC1-06798  https://refugeelab.ca/rllr/2022rllr31
# 2    VC2-07212  https://refugeelab.ca/rllr/2022rllr30
# 3    VC2-06405  https://refugeelab.ca/rllr/2022rllr29
# 4    VC2-06395  https://refugeelab.ca/rllr/2022rllr28
# ..         ...                                    ...
# 534  MB7-21566   https://refugeelab.ca/rllr/2019rllr5
# 535  MB7-18975   https://refugeelab.ca/rllr/2019rllr4
# 536  MB7-18354   https://refugeelab.ca/rllr/2019rllr3
# 537  TB9-01394   https://refugeelab.ca/rllr/2019rllr2
# 538  TB9-04813   https://refugeelab.ca/rllr/2019rllr1
#
# [539 rows x 6 columns]

# %% [markdown]
# ### Scrape html for each case in the table

# %%
# function to get the html from the link
def get_html(link):
    r = requests.get(link)
    if r.status_code == 200:
        time.sleep(.25)
        return r.text
    else:
        return None

df['html'] = df.link.progress_apply(get_html)
# Out:
# 100%|██████████| 539/539 [13:10<00:00,  1.47s/it]

# %%
# export to jsonl raw 
df.to_json('DATA/rllr_cases_raw.jsonl', orient='records', lines=True)

df
# Out:
#          citation   country                         case_type document_date
# 0    2022 RLLR 32    Mexico        PSG: Gender Based Violence    2022/03/08  \
# 1    2022 RLLR 31     Sudan                 Political Opinion    2022/02/03
# 2    2022 RLLR 30  Barbados        PSG: Gender Based Violence    2022/11/28
# 3    2022 RLLR 29   Ukraine        PSG: Gender Based Violence    2022/11/09
# 4    2022 RLLR 28     India                 Political Opinion    2022/09/28
# ..            ...       ...                               ...           ...
# 534   2019 RLLR 5     Haiti                        PSG: SOGIE    2019/10/17
# 535   2019 RLLR 4     Haiti        PSG: Gender Based Violence    2019/07/04
# 536   2019 RLLR 3     Haiti  No Nexus: Criminality/Corruption    2019/09/10
# 537   2019 RLLR 2   Nigeria                        PSG: SOGIE    2019/12/23
# 538   2019 RLLR 1   Nigeria  No Nexus: Criminality/Corruption    2019/10/28
#
#     rpd_number                                   link
# 0    VC1-05483  https://refugeelab.ca/rllr/2022rllr32  \
# 1    VC1-06798  https://refugeelab.ca/rllr/2022rllr31
# 2    VC2-07212  https://refugeelab.ca/rllr/2022rllr30
# 3    VC2-06405  https://refugeelab.ca/rllr/2022rllr29
# 4    VC2-06395  https://refugeelab.ca/rllr/2022rllr28
# ..         ...                                    ...
# 534  MB7-21566   https://refugeelab.ca/rllr/2019rllr5
# 535  MB7-18975   https://refugeelab.ca/rllr/2019rllr4
# 536  MB7-18354   https://refugeelab.ca/rllr/2019rllr3
# 537  TB9-01394   https://refugeelab.ca/rllr/2019rllr2
# 538  TB9-04813   https://refugeelab.ca/rllr/2019rllr1
#
#                                                   html
# 0    <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# 1    <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# 2    <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# 3    <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# 4    <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# ..                                                 ...
# 534  <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# 535  <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# 536  <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# 537  <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
# 538  <!DOCTYPE html><html\nclass=no-js lang=en-CA><...
#
# [539 rows x 7 columns]

# %% [markdown]
# ### Parse html for each case

# %%
# load raw cases
df = pd.read_json('DATA/rllr_cases_raw.jsonl', orient='records', lines=True)

# %%
# function to extract text from html
def get_text(html):

    # if html is None, return None
    if html is None:
        return None

    # extract text from class 'entry-content' in page1 html using beautiful soup
    soup = BeautifulSoup(html, 'html.parser')

    # convert <br> to new line to preserve paragraphs
    for br in soup.find_all('br'):
        br.replace_with('\n')

    # Insert newline characters after each <p> tag to preserve paragraphs
    for p in soup.find_all('p'):
        p.insert_after('\n')


    # extract text from class 'entry-content' (remove \xa0)
    text = soup.find('div', {'class': 'entry-content'}).text.replace('\xa0', ' ')

    # Remove multiple whitespaces and preserve paragraphs
    text = '\n'.join([re.sub(r'\s+', ' ', line.strip()) for line in text.split('\n')])
    return text

df['text'] = df.html.progress_apply(get_text)

# drop html column
df.drop('html', axis=1, inplace=True)
# Out:
# 100%|██████████| 539/539 [00:03<00:00, 137.85it/s]

# %%
# function to extract RPD_member from text
def get_member(text):
    if text is None:
        return None
    else:
        # if text contains 'Panel:' extract the text after 'Panel:' and before the next newline
        if 'Panel:' in text:
            return re.search(r'Panel:(.*)\n', text).group(1).strip()
        else:
            return None
    
df['member'] = df.text.progress_apply(get_member)
# Out:
# 100%|██████████| 539/539 [00:00<00:00, 539682.47it/s]

# %%
# put in standard format for RLL (except "other" field)

# create language column with value "en"
df['language'] = "en"

# create dataset column with value "RLLR"
df['dataset'] = "RLLR"

# create year column with first 4 characters of citation:
df['year'] = df.citation.str[:4]
df['year'] = df['year'].astype(int)

# add a name column with value ""
df['name'] = ""

# rename rpd_number to citation2
df.rename(columns={'rpd_number': 'citation2'}, inplace=True)

# rename link column to source_url
df.rename(columns={'link': 'source_url'}, inplace=True)

# rename text column to unofficial_text
df.rename(columns={'text': 'unofficial_text'}, inplace=True)

# add a scraped timestamp column with today's date in YYYY-MM-DD format as a string
df['scraped_timestamp'] = pd.Timestamp.today().strftime('%Y-%m-%d')

# add a column for other that takes "country", "case_type", and "member" columns
# and puts them in a dictionary using valid json format (as a string)
df['other'] = df[['country', 'case_type', 'member']].to_dict(orient='records')
df['other'] = df['other'].apply(lambda x: json.dumps(x))

# reorder columns
list_cols = ['citation',
             'citation2', 
             'dataset', 
             'year', 
             'name', 
             'language', 
             'document_date', 
             'source_url', 
             'scraped_timestamp', 
             'unofficial_text',
             'other',
             ]

df = df[list_cols]

# %%
# export to json as a single file
df.to_json('DATA/rllr_cases.jsonl', orient='records', lines=True)

df
# Out:
#          citation  citation2 dataset  year name language document_date
# 0    2022 RLLR 32  VC1-05483    RLLR  2022            en    2022/03/08  \
# 1    2022 RLLR 31  VC1-06798    RLLR  2022            en    2022/02/03
# 2    2022 RLLR 30  VC2-07212    RLLR  2022            en    2022/11/28
# 3    2022 RLLR 29  VC2-06405    RLLR  2022            en    2022/11/09
# 4    2022 RLLR 28  VC2-06395    RLLR  2022            en    2022/09/28
# ..            ...        ...     ...   ...  ...      ...           ...
# 534   2019 RLLR 5  MB7-21566    RLLR  2019            en    2019/10/17
# 535   2019 RLLR 4  MB7-18975    RLLR  2019            en    2019/07/04
# 536   2019 RLLR 3  MB7-18354    RLLR  2019            en    2019/09/10
# 537   2019 RLLR 2  TB9-01394    RLLR  2019            en    2019/12/23
# 538   2019 RLLR 1  TB9-04813    RLLR  2019            en    2019/10/28
#
#                                 source_url scraped_timestamp
# 0    https://refugeelab.ca/rllr/2022rllr32        2024-04-11  \
# 1    https://refugeelab.ca/rllr/2022rllr31        2024-04-11
# 2    https://refugeelab.ca/rllr/2022rllr30        2024-04-11
# 3    https://refugeelab.ca/rllr/2022rllr29        2024-04-11
# 4    https://refugeelab.ca/rllr/2022rllr28        2024-04-11
# ..                                     ...               ...
# 534   https://refugeelab.ca/rllr/2019rllr5        2024-04-11
# 535   https://refugeelab.ca/rllr/2019rllr4        2024-04-11
# 536   https://refugeelab.ca/rllr/2019rllr3        2024-04-11
# 537   https://refugeelab.ca/rllr/2019rllr2        2024-04-11
# 538   https://refugeelab.ca/rllr/2019rllr1        2024-04-11
#
#                                        unofficial_text
# 0    Citation: 2022 RLLR 32\nTribunal: Refugee Prot...  \
# 1    Citation: 2022 RLLR 31\nTribunal: Refugee Prot...
# 2    Citation: 2022 RLLR 30\nTribunal: Refugee Prot...
# 3    Citation: 2022 RLLR 29\nTribunal: Refugee Prot...
# 4    Citation: 2022 RLLR 28\nTribunal: Refugee Prot...
# ..                                                 ...
# 534  Citation: 2019 RLLR 5\nTribunal: Refugee Prote...
# 535  Citation: 2019 RLLR 4\nTribunal: Refugee Prote...
# 536  Citation: 2019 RLLR 3\nTribunal: Refugee Prote...
# 537  Citation: 2019 RLLR 2\nTribunal: Refugee Prote...
# 538  Citation: 2019 RLLR 1\nTribunal: Refugee Prote...
#
#                                                  other
# 0    {"country": "Mexico", "case_type": "PSG: Gende...
# 1    {"country": "Sudan", "case_type": "Political O...
# 2    {"country": "Barbados", "case_type": "PSG: Gen...
# 3    {"country": "Ukraine", "case_type": "PSG: Gend...
# 4    {"country": "India", "case_type": "Political O...
# ..                                                 ...
# 534  {"country": "Haiti", "case_type": "PSG: SOGIE"...
# 535  {"country": "Haiti", "case_type": "PSG: Gender...
# 536  {"country": "Haiti", "case_type": "No Nexus: C...
# 537  {"country": "Nigeria", "case_type": "PSG: SOGI...
# 538  {"country": "Nigeria", "case_type": "No Nexus:...
#
# [539 rows x 11 columns]

# %%
# export cleaned df to parquet
df.to_parquet("DATA/rllr_cases.parquet")

# %%
# export cleaned df to yearly json files
for year in tqdm(range(start_year, end_year+1)):
    df[df.year == year].to_json(out_path_yearly / f'{year}.json', orient='records', indent=4)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 275.58it/s]

# %%
# Direct to HF
out_path_HF = pathlib.Path('d:/AI-Projects/canadian-legal-data/RLLR/train.parquet')
df.to_parquet(out_path_HF)

# %% [markdown]
# ### Data verification

# %%
#load json
df = pd.read_json('DATA/rllr_cases.jsonl', orient='records', lines=True)

# convert each item in other dictionary to column
df['other'] = df['other'].apply(lambda x: json.loads(x))
df[['country', 'case_type', 'member']] = df['other'].apply(pd.Series)
df
# Out:
#          citation  citation2 dataset  year name language document_date
# 0    2022 RLLR 32  VC1-05483    RLLR  2022            en    2022/03/08  \
# 1    2022 RLLR 31  VC1-06798    RLLR  2022            en    2022/02/03
# 2    2022 RLLR 30  VC2-07212    RLLR  2022            en    2022/11/28
# 3    2022 RLLR 29  VC2-06405    RLLR  2022            en    2022/11/09
# 4    2022 RLLR 28  VC2-06395    RLLR  2022            en    2022/09/28
# ..            ...        ...     ...   ...  ...      ...           ...
# 534   2019 RLLR 5  MB7-21566    RLLR  2019            en    2019/10/17
# 535   2019 RLLR 4  MB7-18975    RLLR  2019            en    2019/07/04
# 536   2019 RLLR 3  MB7-18354    RLLR  2019            en    2019/09/10
# 537   2019 RLLR 2  TB9-01394    RLLR  2019            en    2019/12/23
# 538   2019 RLLR 1  TB9-04813    RLLR  2019            en    2019/10/28
#
#                                 source_url scraped_timestamp
# 0    https://refugeelab.ca/rllr/2022rllr32        2024-04-11  \
# 1    https://refugeelab.ca/rllr/2022rllr31        2024-04-11
# 2    https://refugeelab.ca/rllr/2022rllr30        2024-04-11
# 3    https://refugeelab.ca/rllr/2022rllr29        2024-04-11
# 4    https://refugeelab.ca/rllr/2022rllr28        2024-04-11
# ..                                     ...               ...
# 534   https://refugeelab.ca/rllr/2019rllr5        2024-04-11
# 535   https://refugeelab.ca/rllr/2019rllr4        2024-04-11
# 536   https://refugeelab.ca/rllr/2019rllr3        2024-04-11
# 537   https://refugeelab.ca/rllr/2019rllr2        2024-04-11
# 538   https://refugeelab.ca/rllr/2019rllr1        2024-04-11
#
#                                        unofficial_text
# 0    Citation: 2022 RLLR 32\nTribunal: Refugee Prot...  \
# 1    Citation: 2022 RLLR 31\nTribunal: Refugee Prot...
# 2    Citation: 2022 RLLR 30\nTribunal: Refugee Prot...
# 3    Citation: 2022 RLLR 29\nTribunal: Refugee Prot...
# 4    Citation: 2022 RLLR 28\nTribunal: Refugee Prot...
# ..                                                 ...
# 534  Citation: 2019 RLLR 5\nTribunal: Refugee Prote...
# 535  Citation: 2019 RLLR 4\nTribunal: Refugee Prote...
# 536  Citation: 2019 RLLR 3\nTribunal: Refugee Prote...
# 537  Citation: 2019 RLLR 2\nTribunal: Refugee Prote...
# 538  Citation: 2019 RLLR 1\nTribunal: Refugee Prote...
#
#                                                  other   country
# 0    {'country': 'Mexico', 'case_type': 'PSG: Gende...    Mexico  \
# 1    {'country': 'Sudan', 'case_type': 'Political O...     Sudan
# 2    {'country': 'Barbados', 'case_type': 'PSG: Gen...  Barbados
# 3    {'country': 'Ukraine', 'case_type': 'PSG: Gend...   Ukraine
# 4    {'country': 'India', 'case_type': 'Political O...     India
# ..                                                 ...       ...
# 534  {'country': 'Haiti', 'case_type': 'PSG: SOGIE'...     Haiti
# 535  {'country': 'Haiti', 'case_type': 'PSG: Gender...     Haiti
# 536  {'country': 'Haiti', 'case_type': 'No Nexus: C...     Haiti
# 537  {'country': 'Nigeria', 'case_type': 'PSG: SOGI...   Nigeria
# 538  {'country': 'Nigeria', 'case_type': 'No Nexus:...   Nigeria
#
#                             case_type             member
# 0          PSG: Gender Based Violence     Kari Schroeder
# 1                   Political Opinion     Siobhan Yorgun
# 2          PSG: Gender Based Violence         Nick Bower
# 3          PSG: Gender Based Violence        Hannah Gray
# 4                   Political Opinion      Kylee Carreno
# ..                                ...                ...
# 534                        PSG: SOGIE    Ethan McMonagle
# 535        PSG: Gender Based Violence    Nicole Ginsberg
# 536  No Nexus: Criminality/Corruption    Me Jean-Guy Jam
# 537                        PSG: SOGIE  Marcelle Bourassa
# 538  No Nexus: Criminality/Corruption  Marcelle Bourassa
#
# [539 rows x 14 columns]

# %%
# function to extract rpd_number from text
def get_rpd_number(text):
    if text is None:
        return None
    else:
        # if text contains 'RPD:' extract the text after 'RPD:' and before the next newline
        if 'RPD Number:' in text:
            return re.search(r'RPD Number:(.*)\n', text).group(1).strip()
        else:
            return None

df['rpd_number'] = df.unofficial_text.progress_apply(get_rpd_number)

# print df where rpd_number2 is not same as rpd_number
df[df.rpd_number != df['citation2']]
# Out:
# 100%|██████████| 539/539 [00:00<00:00, 539424.92it/s]
# Empty DataFrame
# Columns: [citation, citation2, dataset, year, name, language, document_date, source_url, scraped_timestamp, unofficial_text, other, country, case_type, member, rpd_number]
# Index: []

# %%
df.head()
# Out:
#        citation  citation2 dataset  year name language document_date
# 0  2022 RLLR 32  VC1-05483    RLLR  2022            en    2022/03/08  \
# 1  2022 RLLR 31  VC1-06798    RLLR  2022            en    2022/02/03
# 2  2022 RLLR 30  VC2-07212    RLLR  2022            en    2022/11/28
# 3  2022 RLLR 29  VC2-06405    RLLR  2022            en    2022/11/09
# 4  2022 RLLR 28  VC2-06395    RLLR  2022            en    2022/09/28
#
#                               source_url scraped_timestamp
# 0  https://refugeelab.ca/rllr/2022rllr32        2024-04-11  \
# 1  https://refugeelab.ca/rllr/2022rllr31        2024-04-11
# 2  https://refugeelab.ca/rllr/2022rllr30        2024-04-11
# 3  https://refugeelab.ca/rllr/2022rllr29        2024-04-11
# 4  https://refugeelab.ca/rllr/2022rllr28        2024-04-11
#
#                                      unofficial_text
# 0  Citation: 2022 RLLR 32\nTribunal: Refugee Prot...  \
# 1  Citation: 2022 RLLR 31\nTribunal: Refugee Prot...
# 2  Citation: 2022 RLLR 30\nTribunal: Refugee Prot...
# 3  Citation: 2022 RLLR 29\nTribunal: Refugee Prot...
# 4  Citation: 2022 RLLR 28\nTribunal: Refugee Prot...
#
#                                                other   country
# 0  {'country': 'Mexico', 'case_type': 'PSG: Gende...    Mexico  \
# 1  {'country': 'Sudan', 'case_type': 'Political O...     Sudan
# 2  {'country': 'Barbados', 'case_type': 'PSG: Gen...  Barbados
# 3  {'country': 'Ukraine', 'case_type': 'PSG: Gend...   Ukraine
# 4  {'country': 'India', 'case_type': 'Political O...     India
#
#                     case_type          member rpd_number
# 0  PSG: Gender Based Violence  Kari Schroeder  VC1-05483
# 1           Political Opinion  Siobhan Yorgun  VC1-06798
# 2  PSG: Gender Based Violence      Nick Bower  VC2-07212
# 3  PSG: Gender Based Violence     Hannah Gray  VC2-06405
# 4           Political Opinion   Kylee Carreno  VC2-06395
